# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("titanic (1).csv") 
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data["Age"].value_counts() 
data["Age"].median()
# Out:
# 28.0

# %%
plt.boxplot(data["Age"].dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x180a35207a0>,
#   <matplotlib.lines.Line2D at 0x180a3520a70>],
#  'caps': [<matplotlib.lines.Line2D at 0x180a3520d10>,
#   <matplotlib.lines.Line2D at 0x180a3521010>],
#  'boxes': [<matplotlib.lines.Line2D at 0x180a35204d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x180a3521310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x180a3521610>],
#  'means': []}

# %%
plt.hist(data["Age"].dropna())
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
#replacing the blank age by its median 
data['Age'].fillna(data['Age'].median(),inplace=True)
# Out:
# C:\Users\skmis\AppData\Local\Temp\ipykernel_39268\2095516143.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(data['Age'].median(),inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.select_dtypes(include="number").corr() 
# passenger ID not reuired but its obvious.
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.034212 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.064910 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.339898  0.083081  0.018443
# Age             0.034212 -0.064910 -0.339898  1.000000 -0.233296 -0.172482
# SibSp          -0.057527 -0.035322  0.083081 -0.233296  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.172482  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096688  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096688
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#dividing into train and test :

# %%
data=data.drop(['PassengerId','Cabin','Name','Ticket'],axis=1)
data=pd.get_dummies(data,drop_first=True) 
data[data.select_dtypes(bool).columns] = data.select_dtypes(bool).astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Age         891 non-null    float64
#  3   SibSp       891 non-null    int64
#  4   Parch       891 non-null    int64
#  5   Fare        891 non-null    float64
#  6   Sex_male    891 non-null    int32
#  7   Embarked_Q  891 non-null    int32
#  8   Embarked_S  891 non-null    int32
# dtypes: float64(2), int32(3), int64(4)
# memory usage: 52.3 KB

# %%
# train test split  
train_size=0.8
data=data.sample(frac=1,random_state=42) 
train_length = int(data.shape[0]*train_size) 
train_data=data.iloc[:train_length]
test_data=data.iloc[train_length:]

# %%
x_train = train_data.drop("Survived", axis=1)
x_test = test_data.drop("Survived", axis=1)
y_train = train_data["Survived"]
y_test = test_data["Survived"]

# %%
x_train = x_train.values
y_train = y_train.values
x_test = x_test.values
y_test = y_test.values 
x_train
# Out:
# array([[ 3.  , 28.  ,  1.  , ...,  1.  ,  0.  ,  0.  ],
#        [ 2.  , 31.  ,  0.  , ...,  1.  ,  0.  ,  1.  ],
#        [ 3.  , 20.  ,  0.  , ...,  1.  ,  0.  ,  1.  ],
#        ...,
#        [ 3.  , 28.  ,  0.  , ...,  1.  ,  0.  ,  1.  ],
#        [ 3.  ,  2.  ,  4.  , ...,  1.  ,  0.  ,  1.  ],
#        [ 3.  ,  0.42,  0.  , ...,  1.  ,  0.  ,  0.  ]])

# %%
# Normalizing the data using ONLY training statistics to prevent data leakage
x_train_mean = np.mean(x_train, axis=0)
x_train_std = np.std(x_train, axis=0)
x_train = (x_train - x_train_mean) / x_train_std
x_test = (x_test - x_train_mean) / x_train_std

# %%
x_train
# Out:
# array([[ 0.8252333 , -0.09189528,  0.44549532, ...,  0.74242727,
#         -0.308844  , -1.58347376],
#        [-0.37633339,  0.13277572, -0.48196862, ...,  0.74242727,
#         -0.308844  ,  0.63152294],
#        [ 0.8252333 , -0.69101793, -0.48196862, ...,  0.74242727,
#         -0.308844  ,  0.63152294],
#        ...,
#        [ 0.8252333 , -0.09189528, -0.48196862, ...,  0.74242727,
#         -0.308844  ,  0.63152294],
#        [ 0.8252333 , -2.03904389,  3.22788715, ...,  0.74242727,
#         -0.308844  ,  0.63152294],
#        [ 0.8252333 , -2.15737062, -0.48196862, ...,  0.74242727,
#         -0.308844  , -1.58347376]])

# %%
x_train.shape[1] 
def initialise_weights(x_train) : 
    w =np.zeros(x_train.shape[1])
    b=0
    return w,b

# %%
def linear_reg(x,w,b) : 
    return np.dot(x,w)+b  

def sigmoid(z) : 
    
    return 1/(1+np.exp(-z))


def compute_cost(y_train , y_pred) :  
   
   
    cost = (-1/y_train.shape[0]) * np.sum(y_train*np.log(y_pred) + (1-y_train)*np.log(1-y_pred))
    return cost

def gradiant_descent(X,y_pred,y_true,weights, bias, learning_rate) :  
    m=X.shape[0]
    dw = (1/m) * np.dot(X.T, (y_pred - y_true))
    db = (1/m) * np.sum(y_pred - y_true)
    
   
    weights = weights - learning_rate * dw
    bias = bias - learning_rate * db
    
    return weights, bias

# %%
iterations = 500
learning_rate = 0.05  
cost_history_train = []

w,b = initialise_weights(x_train)
for i in range(iterations) : 
    z_pred = linear_reg(x_train,w,b) 
    y_pred = sigmoid(z_pred) 
    cost = compute_cost(y_train,y_pred) 
    cost_history_train.append(cost)
    w,b = gradiant_descent(x_train,y_pred,y_train,w,b,learning_rate) 
    if i%10 == 0 : 
        print(f"Cost after {i} iterations : {cost}")
# Out:
# Cost after 0 iterations : 0.6931471805599453
# Cost after 10 iterations : 0.6366291462949016
# Cost after 20 iterations : 0.5966141015877419
# Cost after 30 iterations : 0.5674759866828172
# Cost after 40 iterations : 0.5456691913016481
# Cost after 50 iterations : 0.528948174200172
# Cost after 60 iterations : 0.5158555212022515
# Cost after 70 iterations : 0.5054180308867703
# Cost after 80 iterations : 0.4969676930893169
# Cost after 90 iterations : 0.4900342517554334
# Cost after 100 iterations : 0.48427904396552895
# Cost after 110 iterations : 0.47945315377766906
# Cost after 120 iterations : 0.4753702595582998
# Cost after 130 iterations : 0.4718885921581534
# Cost after 140 iterations : 0.46889868276028807
# Cost after 150 iterations : 0.4663148750335257
# Cost after 160 iterations : 0.46406933696928526
# Cost after 170 iterations : 0.4621077651773676
# Cost after 180 iterations : 0.46038625573834724
# Cost after 190 iterations : 0.45886899245768437
# Cost after 200 iterations : 0.45752651663308214
# Cost after 210 iterations : 0.45633441637753586
# Cost after 220 iterations : 0.45527232262521256
# Cost after 230 iterations : 0.4543231320548698
# Cost after 240 iterations : 0.45347239982694787
# Cost after 250 iterations : 0.4527078607554757
# Cost after 260 iterations : 0.4520190485882032
# Cost after 270 iterations : 0.4513969909301194
# Cost after 280 iterations : 0.45083396300120154
# Cost after 290 iterations : 0.4503232875313502
# Cost after 300 iterations : 0.44985917111547313
# Cost after 310 iterations : 0.4494365695908056
# Cost after 320 iterations : 0.44905107667374017
# Cost after 330 iterations : 0.4486988313574964
# Cost after 340 iterations : 0.4483764405335602
# Cost after 350 iterations : 0.44808091403703176
# Cost after 360 iterations : 0.4478096098853445
# Cost after 370 iterations : 0.44756018792259755
# Cost after 380 iterations : 0.4473305704283831
# Cost after 390 iterations : 0.4471189085231044
# Cost after 400 iterations : 0.4469235534182434
# Cost after 410 iterations : 0.4467430317326046
# Cost after 420 iterations : 0.44657602423387166
# Cost after 430 iterations : 0.4464213474762464
# Cost after 440 iterations : 0.4462779378951703
# Cost after 450 iterations : 0.44614483799351873
# Cost after 460 iterations : 0.44602118431363635
# Cost after 470 iterations : 0.44590619693879524
# Cost after 480 iterations : 0.4457991703082088
# Cost after 490 iterations : 0.4456994651632747

# %%
z_pred_test = linear_reg(x_test,w,b) 
y_pred_test = sigmoid(z_pred_test) 
cost_test = compute_cost(y_test,y_pred_test) 
print(cost_test)
# Out:
# 0.4320077299015218

# %%
plt.plot(range(iterations),cost_history_train)

# %%
def loss(y_true, y_pred): 
    n_samples = y_true.shape[0]
    distances = 1 - y_true * y_pred
    distances = np.maximum(0, distances)
    hinge_loss = np.mean(distances)
    return hinge_loss

# %%
class SVM : 
    def __init__(self, learning_rate=0.05, lamdbda_param=0.1, n_iters=100): 
        self.learning_rate = learning_rate 
        self.lamdbda_param = lamdbda_param
        self.n_iters = n_iters 
        self.weights = None
        self.bias = None

    def fit(self, X, y): 
        n_samples, n_features = X.shape 
        y = np.where(y<=0, -1, 1) 
        self.weights = np.zeros(n_features)
        self.bias = 0   
        for iteration in range(self.n_iters): 
            for idx, x_i in enumerate(X):  # enumerate give index value pairs  
                condition = y[idx] * (np.dot(x_i, self.weights) - self.bias) >= 1
                if condition: 
                    self.weights -= self.learning_rate * (2 * self.lamdbda_param * self.weights)
                else: 
                    self.weights -= self.learning_rate * (2 * self.lamdbda_param * self.weights - np.dot(x_i, y[idx]))
                    self.bias -= self.learning_rate * y[idx] 
            
            # Print loss every 100th iteration
            if iteration % 10 == 0:
                y_pred = np.dot(X, self.weights) - self.bias
                hinge_loss = loss(y, y_pred)
                print(f"Iteration {iteration}: Loss = {hinge_loss:.4f}")

    def predict(self, X):  
        linear_output = np.dot(X, self.weights) - self.bias
        return np.sign(linear_output)

# %%
SVM_model = SVM(learning_rate=0.001, lamdbda_param=0.1, n_iters=400) 
SVM_model.fit(x_train, y_train)
y_pred = SVM_model.predict(x_test)
# Out:
# Iteration 0: Loss = 0.6622
# Iteration 10: Loss = 0.4550
# Iteration 20: Loss = 0.4492
# Iteration 30: Loss = 0.4483
# Iteration 40: Loss = 0.4483
# Iteration 50: Loss = 0.4485
# Iteration 60: Loss = 0.4482
# Iteration 70: Loss = 0.4479
# Iteration 80: Loss = 0.4480
# Iteration 90: Loss = 0.4481
# Iteration 100: Loss = 0.4482
# Iteration 110: Loss = 0.4482
# Iteration 120: Loss = 0.4485
# Iteration 130: Loss = 0.4484
# Iteration 140: Loss = 0.4482
# Iteration 150: Loss = 0.4486
# Iteration 160: Loss = 0.4483
# Iteration 170: Loss = 0.4486
# Iteration 180: Loss = 0.4483
# Iteration 190: Loss = 0.4486
# Iteration 200: Loss = 0.4484
# Iteration 210: Loss = 0.4482
# Iteration 220: Loss = 0.4481
# Iteration 230: Loss = 0.4482
# Iteration 240: Loss = 0.4484
# Iteration 250: Loss = 0.4483
# Iteration 260: Loss = 0.4482
# Iteration 270: Loss = 0.4484
# Iteration 280: Loss = 0.4483
# Iteration 290: Loss = 0.4484
# Iteration 300: Loss = 0.4484
# Iteration 310: Loss = 0.4484
# Iteration 320: Loss = 0.4484
# Iteration 330: Loss = 0.4480
# Iteration 340: Loss = 0.4483
# Iteration 350: Loss = 0.4482
# Iteration 360: Loss = 0.4484
# Iteration 370: Loss = 0.4486
# Iteration 380: Loss = 0.4482
# Iteration 390: Loss = 0.4484

# %%
def svm_loss(X, y, w, b, lambda_param):
    
    y_converted = np.where(y <= 0, -1, 1)
    margins = 1 - y_converted * (np.dot(X, w) + b)
    hinge_loss = np.maximum(0, margins)
    return lambda_param * np.dot(w, w) + np.mean(hinge_loss) 


test_loss = svm_loss(x_test, y_test, SVM_model.weights, SVM_model.bias, SVM_model.lamdbda_param) 
print(test_loss)
# Out:
# 0.7649673697904279

# %%
def classification_metrics_svm(y_true, y_pred):
    TP = TN = FP = FN = 0

    for yt, yp in zip(y_true, y_pred):
        if yt == 1 and yp == 1:
            TP += 1
        elif yt == -1 and yp == -1:
            TN += 1
        elif yt == -1 and yp == 1:
            FP += 1
        elif yt == 1 and yp == -1:
            FN += 1

    accuracy = (TP + TN) / (TP + TN + FP + FN)
    precision = TP / (TP + FP) if (TP + FP) != 0 else 0
    recall = TP / (TP + FN) if (TP + FN) != 0 else 0
    f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) != 0 else 0

    print("TP:", TP, "FP:", FP, "FN:", FN, "TN:", TN)
    return accuracy, precision, recall, f1 

y_test = np.where(y_test <= 0, -1, 1) 
accuracy, precision, recall, f1 = classification_metrics_svm(y_test, y_pred) 
print(accuracy, precision, recall, f1)
# Out:
# TP: 46 FP: 15 FN: 19 TN: 99
# 0.8100558659217877 0.7540983606557377 0.7076923076923077 0.7301587301587301
